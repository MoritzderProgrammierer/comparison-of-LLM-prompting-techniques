# %% [markdown]
# Evaluate Data here

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("mlflow_data/mlflow_all_runs_data.csv")
df.head()
# Out:
#                              run_id                     parent_run_id  \
# 0  419b52fbcc094e1988be22d64825e44d                               NaN
# 1  fb4a33581b9b49bea019cf2e2d5bf865  419b52fbcc094e1988be22d64825e44d
# 2  6b581fb8c5f9405db300c86c67ef9d7c  fb4a33581b9b49bea019cf2e2d5bf865
# 3  9c6f1d843b5b4c579459d1e56436d52a  fb4a33581b9b49bea019cf2e2d5bf865
# 4  aaa64853a0c440c0a0a1d6cc100a7c59  fb4a33581b9b49bea019cf2e2d5bf865
#
#       start_time       end_time       params.data_file_used  \
# 0  1738363599913  1738403592492  ./data/machine_translation
# 1  1738371133680  1738403586854                         NaN
# 2  1738396797629  1738403586801                         NaN
# 3  1738394137352  1738396797613                         NaN
# 4  1738387338262  1738394137333                         NaN
#
#    metrics.avg_BERTScore_both_over_all_models_AllTogetherStrategy  \
# 0                                           0.545937
# 1                                                NaN
# ...

# %%
#df = df.drop(columns=['params.data_file_used', 'column_nameB'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Columns: 128 entries, run_id to metrics.ROUGEL_eng2de_science
# dtypes: float64(115), int64(2), object(11)
# memory usage: 33.1+ KB

# %%
pipeline = df[df["run_id"]=="419b52fbcc094e1988be22d64825e44d"]
pipeline = pipeline.dropna(axis=1, how='all')
pipeline.head()
# Out:
#                              run_id     start_time       end_time  \
# 0  419b52fbcc094e1988be22d64825e44d  1738363599913  1738403592492
#
#         params.data_file_used  \
# 0  ./data/machine_translation
#
#    metrics.avg_BERTScore_both_over_all_models_AllTogetherStrategy  \
# 0                                           0.545937
#
#    metrics.avg_BERTScore_both_over_all_models_ComparisonStrategy  \
# 0                                           0.613384
#
#    metrics.avg_BERTScore_both_over_all_models_FewShotStrategy  \
# 0                                           0.512552
#
#    metrics.avg_BERTScore_both_over_all_models_InstructionStrategy  \
# 0                                           0.535713
#
#    metrics.avg_BERTScore_both_over_all_models_PersonaStrategy  \
# 0                                           0.640439
#
#    metrics.avg_BERTScore_both_over_all_models_SelfCorrectStrategy  ...  \
# 0                                           0.603922               ...
#
# ...

# %%
gemma = df[df["run_id"]=="ce6f638d8823498ab1a908b9567ed057"]
gemma = gemma.dropna(axis=1, how='all')
llama32 = df[df["run_id"]=="ce6f638d8823498ab1a908b9567ed057"]
llama32 = llama32.dropna(axis=1, how='all')
llama31 = df[df["run_id"]=="ce6f638d8823498ab1a908b9567ed057"]
llama31 = llama31.dropna(axis=1, how='all')
aya = df[df["run_id"]=="ce6f638d8823498ab1a908b9567ed057"]
aya = aya.dropna(axis=1, how='all')
